# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# 애플 주가 데이터 불러오기
file_path = '/content/drive/MyDrive/Colab Notebooks/data/AAPL주가데이터.csv'
data = pd.read_csv(file_path, index_col=0, parse_dates=True)

# 사용하려는 컬럼 선택 (Close, Volume, RSI, MACD, Signal, MACD_Hist, Upper_Band, Middle_Band, Lower_Band)
columns_to_use = ['Close', 'Volume', 'RSI', 'MACD', 'Signal', 'MACD_Hist', 'Upper_Band', 'Middle_Band', 'Lower_Band']
data = data[columns_to_use]

# 데이터 기간 설정 (끝나는 날짜는 2024-06-27로 고정)
end_date = '2024-06-27'

# 5년, 10년 기간 설정
five_years_start_date = '2019-06-28'
ten_years_start_date = '2014-06-30'

# 각 기간에 대해 데이터를 분할
five_year_data = data.loc[five_years_start_date:end_date]
ten_year_data = data.loc[ten_years_start_date:end_date]

# 각 데이터 확인
print("5년 데이터:\n", five_year_data.head())
print("10년 데이터:\n", ten_year_data.head())
# Out:
# 5년 데이터:
#                  Close     Volume        RSI      MACD    Signal  MACD_Hist  \
# Date
# 2019-06-28  49.480000  124442400  62.037868  0.678493  0.495783   0.182709
# 2019-07-01  50.387501  109012000  64.291783  0.727872  0.542201   0.185671
# 2019-07-02  50.682499   67740800  67.688470  0.781797  0.590120   0.191677
# 2019-07-03  51.102501   45448000  69.899167  0.848641  0.641824   0.206817
# 2019-07-05  51.057499   69062000  73.401185  0.887751  0.691010   0.196741
#
#             Upper_Band  Middle_Band  Lower_Band
# Date
# 2019-06-28   51.930511    48.242250   44.553989
# 2019-07-01   51.588151    48.595375   45.602600
# 2019-07-02   51.465405    48.884000   46.302595
# 2019-07-03   51.429560    49.157375   46.885190
# 2019-07-05   51.388069    49.395000   47.401932
# 10년 데이터:
#                  Close     Volume        RSI      MACD    Signal  MACD_Hist  \
# Date
# 2014-06-30  23.232500  197929200  42.378751  0.057073  0.069856  -0.012783
# 2014-07-01  23.379999  152892000  48.081240  0.091136  0.074112   0.017023
# 2014-07-02  23.370001  113860000  58.117358  0.115986  0.082487   0.033499
# 2014-07-03  23.507500   91567200  70.014615  0.145103  0.095010   0.050093
# 2014-07-07  23.992500  225872000  73.891076  0.204951  0.116998   0.087953
#
#             Upper_Band  Middle_Band  Lower_Band
# Date
# 2014-06-30   23.553829    22.997339   22.440850
# 2014-07-01   23.598517    23.027875   22.457233
# 2014-07-02   23.635717    23.044911   22.454104
# 2014-07-03   23.689878    23.064304   22.438729
# 2014-07-07   23.861776    23.111125   22.360474

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# 가장 긴 기간(10년치) 데이터를 기준으로 MinMaxScaler를 생성
scalers = {}
scaled_data = {}

# 각 컬럼에 대해 MinMaxScaler를 적용하여 데이터 정규화
for column in ten_year_data.columns:
    scaler = MinMaxScaler()
    scaler.fit(ten_year_data[[column]])
    scalers[column] = scaler
    scaled_data[column] = {
        'five_year': scaler.transform(five_year_data[[column]]),
        'ten_year': scaler.transform(ten_year_data[[column]])
    }

# 정규화된 데이터를 DataFrame으로 변환
five_year_scaled = pd.DataFrame({col: scaled_data[col]['five_year'].flatten() for col in ten_year_data.columns},
                                index=five_year_data.index)

ten_year_scaled = pd.DataFrame({col: scaled_data[col]['ten_year'].flatten() for col in ten_year_data.columns},
                               index=ten_year_data.index)

# 결과 확인
print("5년치 정규화된 데이터:\n", five_year_scaled.head())
print("10년치 정규화된 데이터:\n", ten_year_scaled.head())
# Out:
# 5년치 정규화된 데이터:
#                 Close    Volume       RSI      MACD    Signal  MACD_Hist  \
# Date
# 2019-06-28  0.138573  0.136528  0.634728  0.495740  0.496528   0.550807
# 2019-07-01  0.143249  0.115544  0.659020  0.499070  0.500179   0.551412
# 2019-07-02  0.144769  0.059418  0.695627  0.502706  0.503949   0.552641
# 2019-07-03  0.146933  0.029102  0.719452  0.507214  0.508017   0.555737
# 2019-07-05  0.146701  0.061215  0.757194  0.509851  0.511886   0.553676
#
#             Upper_Band  Middle_Band  Lower_Band
# Date
# 2019-06-28    0.142228     0.139015    0.138168
# 2019-07-01    0.140512     0.140959    0.144391
# 2019-07-02    0.139896     0.142549    0.148544
# 2019-07-03    0.139717     0.144054    0.152001
# 2019-07-05    0.139509     0.145363    0.155067
# 10년치 정규화된 데이터:
#                 Close    Volume       RSI      MACD    Signal  MACD_Hist  \
# Date
# 2014-06-30  0.003336  0.236464  0.422857  0.453836  0.463020   0.510829
# 2014-07-01  0.004096  0.175217  0.484314  0.456133  0.463355   0.516925
# 2014-07-02  0.004045  0.122137  0.592476  0.457809  0.464013   0.520294
# 2014-07-03  0.004753  0.091820  0.720696  0.459772  0.464999   0.523687
# 2014-07-07  0.007252  0.274464  0.762474  0.463808  0.466728   0.531430
#
#             Upper_Band  Middle_Band  Lower_Band
# Date
# 2014-06-30    0.000000     0.000000    0.006954
# 2014-07-01    0.000224     0.000168    0.007051
# 2014-07-02    0.000410     0.000262    0.007033
# 2014-07-03    0.000682     0.000369    0.006941
# 2014-07-07    0.001543     0.000627    0.006477

# %%
import numpy as np

# 데이터셋 분리 함수
def create_sliding_window_dataset(data, window_size, prediction_offsets):
    X, y = [], []
    for i in range(len(data) - window_size - max(prediction_offsets) + 1):
        X.append(data.iloc[i:(i + window_size)].values)
        y.append([data.iloc[i + window_size + offset - 1]['Close'] for offset in prediction_offsets])
    return np.array(X), np.array(y)

# 슬라이딩 윈도우 크기와 예측 오프셋 설정
window_size = 20
prediction_offsets = [1, 2, 3, 4, 5]

# 5년치와 10년치 데이터에 대해 슬라이딩 윈도우 방식으로 분리
five_year_X, five_year_y = create_sliding_window_dataset(five_year_scaled, window_size, prediction_offsets)
ten_year_X, ten_year_y = create_sliding_window_dataset(ten_year_scaled, window_size, prediction_offsets)

# Train/Validation/Test 셋으로 분리하는 함수
def split_data(X, y, train_ratio=0.6, validation_ratio=0.2):
    train_size = int(len(X) * train_ratio)
    validation_size = int(len(X) * validation_ratio)
    X_train = X[:train_size]
    y_train = y[:train_size]
    X_validation = X[train_size:train_size + validation_size]
    y_validation = y[train_size:train_size + validation_size]
    X_test = X[train_size + validation_size:]
    y_test = y[train_size + validation_size:]
    return X_train, y_train, X_validation, y_validation, X_test, y_test

# 5년치와 10년치 데이터에 대해 Train/Validation/Test 셋으로 분리
five_year_train_X, five_year_train_y, five_year_val_X, five_year_val_y, five_year_test_X, five_year_test_y = split_data(five_year_X, five_year_y)
ten_year_train_X, ten_year_train_y, ten_year_val_X, ten_year_val_y, ten_year_test_X, ten_year_test_y = split_data(ten_year_X, ten_year_y)

# 결과 확인
print("5년치 데이터 분할 (Train/Validation/Test):")
print(f"Train: {five_year_train_X.shape}, Validation: {five_year_val_X.shape}, Test: {five_year_test_X.shape}")

print("10년치 데이터 분할 (Train/Validation/Test):")
print(f"Train: {ten_year_train_X.shape}, Validation: {ten_year_val_X.shape}, Test: {ten_year_test_X.shape}")
# Out:
# 5년치 데이터 분할 (Train/Validation/Test):
# Train: (740, 20, 9), Validation: (246, 20, 9), Test: (248, 20, 9)
# 10년치 데이터 분할 (Train/Validation/Test):
# Train: (1495, 20, 9), Validation: (498, 20, 9), Test: (499, 20, 9)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pandas as pd

# Transformer 모델 생성 함수
def create_transformer_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, dropout_rate=0.2):
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = LayerNormalization(epsilon=1e-6)(x)
        x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout_rate)(x, x)
        x = Dropout(dropout_rate)(x)
        x = LayerNormalization(epsilon=1e-6)(x)
        x = Dense(ff_dim, activation="relu")(x)
        x = Dropout(dropout_rate)(x)

    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1)(x)  # 종가를 예측하므로 출력 유닛 수는 1

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# 모델 학습 및 평가 함수
def train_and_evaluate_model(train_X, train_y, val_X, val_y, test_X, test_y, scaler, period_name, head_size, num_heads, ff_dim, num_transformer_blocks, batch_size):
    input_shape = (train_X.shape[1], train_X.shape[2])  # 입력 데이터의 형태
    model = create_transformer_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, dropout_rate=0.2)

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # train_y, val_y, test_y를 1차원으로 변환 (단일 Close 값만 예측하기 때문)
    train_y = train_y[:, 0]
    val_y = val_y[:, 0]
    test_y = test_y[:, 0]

    history = model.fit(train_X, train_y, epochs=100, batch_size=batch_size, validation_data=(val_X, val_y),
                        callbacks=[early_stopping], verbose=1)

    # 모델 평가
    test_predictions = model.predict(test_X).flatten()
    test_rmse = np.sqrt(mean_squared_error(test_y, test_predictions))

    # 예측된 값과 실제 값을 원래 스케일로 변환
    test_y_original = scaler.inverse_transform(test_y.reshape(-1, 1)).flatten()
    test_predictions_original = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

    return test_rmse, model, history, test_y_original, test_predictions_original

# 하이퍼파라미터 튜닝을 위한 설정
head_size_list = [64, 128]  # 헤드 사이즈를 64, 128로 설정
num_heads_list = [4, 8]  # 멀티 헤드 수를 4, 8로 설정
ff_dim_list = [128, 256]  # 피드포워드 레이어의 차원을 128, 256으로 설정
num_transformer_blocks_list = [2]  # Transformer 블록 수를 1, 2로 설정


# 튜닝 결과 저장용 리스트
tuning_results = []
prediction_results = []

# 각 기간별 데이터 학습 및 평가
periods = {
    '5_years': (five_year_train_X, five_year_train_y, five_year_val_X, five_year_val_y, five_year_test_X, five_year_test_y, scalers['Close']),
    '10_years': (ten_year_train_X, ten_year_train_y, ten_year_val_X, ten_year_val_y, ten_year_test_X, ten_year_test_y, scalers['Close'])
}

best_models = {}
histories = {}
best_results = {}
best_predictions = {}

for period_name, (train_X, train_y, val_X, val_y, test_X, test_y, scaler) in periods.items():
    best_rmse = float('inf')
    best_params = None
    best_test_predictions = None
    best_test_y = None
    for head_size, num_heads, ff_dim, num_transformer_blocks in itertools.product(head_size_list, num_heads_list, ff_dim_list, num_transformer_blocks_list):
        print(f"\nTraining and evaluating for period: {period_name} with head_size: {head_size}, num_heads: {num_heads}, ff_dim: {ff_dim}, num_transformer_blocks: {num_transformer_blocks}")
        test_rmse, model, history, test_y_values, test_predictions = train_and_evaluate_model(
            train_X, train_y, val_X, val_y, test_X, test_y, scaler, period_name, head_size, num_heads, ff_dim, num_transformer_blocks, batch_size=32
        )
        tuning_results.append([period_name, head_size, num_heads, ff_dim, num_transformer_blocks, test_rmse])

        if test_rmse < best_rmse:
            best_rmse = test_rmse
            best_params = (head_size, num_heads, ff_dim, num_transformer_blocks)
            best_models[period_name] = model
            histories[period_name] = history
            best_results[period_name] = test_rmse
            best_test_predictions = test_predictions
            best_test_y = test_y_values

    # 예측값과 실제값 저장
    prediction_results.extend(
        list(zip([period_name] * len(best_test_y), range(len(best_test_y)), best_test_y, best_test_predictions))
    )
    best_predictions[period_name] = (best_test_y, best_test_predictions)

    print(f"Best RMSE for period {period_name}: {best_rmse} with params: {best_params}")

# 하이퍼파라미터 튜닝 결과를 CSV 파일로 저장
tuning_results_df = pd.DataFrame(tuning_results, columns=['Period', 'Head_Size', 'Num_Heads', 'FF_Dim', 'Num_Transformer_Blocks', 'Test_RMSE'])
tuning_results_df.to_csv('/content/AAPL_Transformer_D1_tuning.csv', index=False)

# 예측값과 실제값 결과를 CSV 파일로 저장
prediction_results_df = pd.DataFrame(prediction_results, columns=['Period', 'Index', 'Actual', 'Predicted'])
prediction_results_df.to_csv('/content/AAPL_Transformer_D1_prediction.csv', index=False)

# RMSE를 바 차트로 시각화
period_names = ['5_years', '10_years']
rmse_values = [best_results[period] for period in period_names]

plt.figure(figsize=(10, 6))
plt.bar(period_names, rmse_values, color='skyblue')
plt.xlabel('Period')
plt.ylabel('RMSE (Normalized)')
plt.title('RMSE for Different Periods')
plt.show()

# 변수에 저장 (다음 블럭에서 시각화에 사용하기 위해)
best_test_y_predictions = best_predictions
# Out:
# Training and evaluating for period: 5_years with head_size: 64, num_heads: 4, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 94ms/step - loss: 2.2723 - val_loss: 0.0380
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.1267 - val_loss: 0.0180
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0483 - val_loss: 0.0142
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0349 - val_loss: 0.0114
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0276 - val_loss: 0.0412
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0201 - val_loss: 0.0474
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0158 - val_loss: 0.0634
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0148 - val_loss: 0.0351
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0175 - val_loss: 0.0570
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0149 - val_loss: 0.0672
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0129 - val_loss: 0.0560
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0129 - val_loss: 0.0506
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 0.0127 - val_loss: 0.0471
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0115 - val_loss: 0.0939
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
#
# Training and evaluating for period: 5_years with head_size: 64, num_heads: 4, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 187ms/step - loss: 3.5254 - val_loss: 0.0149
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0755 - val_loss: 0.0155
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0280 - val_loss: 0.0275
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 0.0244 - val_loss: 0.0167
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - loss: 0.0161 - val_loss: 0.0172
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0161 - val_loss: 0.0281
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0153 - val_loss: 0.0322
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - loss: 0.0133 - val_loss: 0.0413
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0103 - val_loss: 0.0485
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 0.0119 - val_loss: 0.0591
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0109 - val_loss: 0.0734
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step
#
# Training and evaluating for period: 5_years with head_size: 64, num_heads: 8, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 218ms/step - loss: 1.9823 - val_loss: 0.0339
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0714 - val_loss: 0.0362
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0354 - val_loss: 0.0373
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.0232 - val_loss: 0.0484
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0199 - val_loss: 0.0715
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - loss: 0.0175 - val_loss: 0.0747
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0183 - val_loss: 0.0644
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - loss: 0.0131 - val_loss: 0.0922
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 0.0131 - val_loss: 0.0491
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0125 - val_loss: 0.0715
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0136 - val_loss: 0.0695
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78c35074e440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
#
# Training and evaluating for period: 5_years with head_size: 64, num_heads: 8, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 286ms/step - loss: 5.0137 - val_loss: 0.0217
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - loss: 0.1460 - val_loss: 0.0118
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - loss: 0.0630 - val_loss: 0.0273
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.0448 - val_loss: 0.0208
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - loss: 0.0207 - val_loss: 0.0254
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 206ms/step - loss: 0.0180 - val_loss: 0.0493
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - loss: 0.0156 - val_loss: 0.0469
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - loss: 0.0151 - val_loss: 0.0580
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - loss: 0.0130 - val_loss: 0.0513
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.0133 - val_loss: 0.0700
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0104 - val_loss: 0.0792
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 193ms/step - loss: 0.0113 - val_loss: 0.0806
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78c35306ed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
#
# Training and evaluating for period: 5_years with head_size: 128, num_heads: 4, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - loss: 2.1425 - val_loss: 0.0205
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0603 - val_loss: 0.0281
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0252 - val_loss: 0.0261
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - loss: 0.0190 - val_loss: 0.0253
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0157 - val_loss: 0.0324
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0146 - val_loss: 0.0231
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0147 - val_loss: 0.0278
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0139 - val_loss: 0.0523
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0131 - val_loss: 0.0560
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 0.0121 - val_loss: 0.0383
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - loss: 0.0128 - val_loss: 0.0464
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
#
# Training and evaluating for period: 5_years with head_size: 128, num_heads: 4, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 316ms/step - loss: 3.0558 - val_loss: 0.0939
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - loss: 0.2087 - val_loss: 0.0713
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0770 - val_loss: 0.0321
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - loss: 0.0459 - val_loss: 0.0506
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 190ms/step - loss: 0.0291 - val_loss: 0.0283
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.0231 - val_loss: 0.0216
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - loss: 0.0215 - val_loss: 0.0195
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0159 - val_loss: 0.0143
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - loss: 0.0124 - val_loss: 0.0307
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - loss: 0.0136 - val_loss: 0.0184
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0131 - val_loss: 0.0247
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0107 - val_loss: 0.0210
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 191ms/step - loss: 0.0116 - val_loss: 0.0189
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - loss: 0.0108 - val_loss: 0.0175
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0102 - val_loss: 0.0245
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - loss: 0.0097 - val_loss: 0.0292
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - loss: 0.0098 - val_loss: 0.0330
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 187ms/step - loss: 0.0117 - val_loss: 0.0548
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step
#
# Training and evaluating for period: 5_years with head_size: 128, num_heads: 8, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 232ms/step - loss: 1.9238 - val_loss: 0.1078
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - loss: 0.0524 - val_loss: 0.0479
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - loss: 0.0274 - val_loss: 0.0248
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 293ms/step - loss: 0.0244 - val_loss: 0.0463
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0166 - val_loss: 0.0539
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 300ms/step - loss: 0.0164 - val_loss: 0.0437
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 217ms/step - loss: 0.0156 - val_loss: 0.0601
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - loss: 0.0136 - val_loss: 0.0812
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.0136 - val_loss: 0.0664
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 313ms/step - loss: 0.0123 - val_loss: 0.0768
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.0131 - val_loss: 0.0513
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - loss: 0.0131 - val_loss: 0.0748
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.0110 - val_loss: 0.0890
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step
#
# Training and evaluating for period: 5_years with head_size: 128, num_heads: 8, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 559ms/step - loss: 5.2568 - val_loss: 0.0080
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 20s 533ms/step - loss: 0.0871 - val_loss: 0.0283
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 455ms/step - loss: 0.0529 - val_loss: 0.0213
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 527ms/step - loss: 0.0277 - val_loss: 0.0182
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 545ms/step - loss: 0.0230 - val_loss: 0.0195
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 454ms/step - loss: 0.0189 - val_loss: 0.0503
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 547ms/step - loss: 0.0163 - val_loss: 0.0673
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 484ms/step - loss: 0.0145 - val_loss: 0.0590
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 531ms/step - loss: 0.0154 - val_loss: 0.0601
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 19s 472ms/step - loss: 0.0134 - val_loss: 0.0675
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 549ms/step - loss: 0.0127 - val_loss: 0.0691
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step
# Best RMSE for period 5_years: 0.057189053186822214 with params: (128, 4, 128, 2)
#
# Training and evaluating for period: 10_years with head_size: 64, num_heads: 4, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - loss: 0.8307 - val_loss: 1.4123
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0156 - val_loss: 1.0841
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0100 - val_loss: 0.8296
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0070 - val_loss: 0.6965
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0065 - val_loss: 0.4383
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0051 - val_loss: 0.3319
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0043 - val_loss: 0.2621
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.0036 - val_loss: 0.2455
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0033 - val_loss: 0.3433
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0031 - val_loss: 0.2764
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - loss: 0.0024 - val_loss: 0.2458
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0024 - val_loss: 0.2213
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0021 - val_loss: 0.2377
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0017 - val_loss: 0.2697
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.0017 - val_loss: 0.3602
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0016 - val_loss: 0.3301
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0012 - val_loss: 0.3165
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 0.0014 - val_loss: 0.2194
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0013 - val_loss: 0.1871
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0012 - val_loss: 0.1946
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 0.0014 - val_loss: 0.1352
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 0.0012 - val_loss: 0.1756
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0011 - val_loss: 0.1434
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.0012 - val_loss: 0.1228
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0012 - val_loss: 0.1101
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - loss: 0.0011 - val_loss: 0.1111
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.0011 - val_loss: 0.1252
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0010 - val_loss: 0.1215
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0011 - val_loss: 0.0816
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 0.0010 - val_loss: 0.0744
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 9.5919e-04 - val_loss: 0.0760
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0010 - val_loss: 0.0713
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 9.5696e-04 - val_loss: 0.0703
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 8.0062e-04 - val_loss: 0.0842
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.6305e-04 - val_loss: 0.1113
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 8.4841e-04 - val_loss: 0.0869
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 8.8953e-04 - val_loss: 0.0921
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 8.5145e-04 - val_loss: 0.1107
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 7.8634e-04 - val_loss: 0.1322
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - loss: 8.6418e-04 - val_loss: 0.1203
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 7.8795e-04 - val_loss: 0.1305
# Epoch 42/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 7.0078e-04 - val_loss: 0.1329
# Epoch 43/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 8.6252e-04 - val_loss: 0.0920
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# Training and evaluating for period: 10_years with head_size: 64, num_heads: 4, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - loss: 3.3599 - val_loss: 5.7956
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 0.0304 - val_loss: 6.1647
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - loss: 0.0131 - val_loss: 6.7644
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - loss: 0.0100 - val_loss: 7.1492
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 185ms/step - loss: 0.0084 - val_loss: 6.9656
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 0.0076 - val_loss: 7.1430
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 175ms/step - loss: 0.0068 - val_loss: 7.1507
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - loss: 0.0062 - val_loss: 6.9257
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - loss: 0.0050 - val_loss: 5.7508
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.0048 - val_loss: 4.6429
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - loss: 0.0042 - val_loss: 3.8371
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - loss: 0.0035 - val_loss: 3.2121
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - loss: 0.0031 - val_loss: 2.4726
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - loss: 0.0028 - val_loss: 1.7780
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 153ms/step - loss: 0.0024 - val_loss: 1.2538
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - loss: 0.0024 - val_loss: 0.9563
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - loss: 0.0019 - val_loss: 0.9032
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - loss: 0.0018 - val_loss: 0.7382
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - loss: 0.0017 - val_loss: 0.5615
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - loss: 0.0015 - val_loss: 0.4634
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - loss: 0.0015 - val_loss: 0.3730
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - loss: 0.0015 - val_loss: 0.3193
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - loss: 0.0013 - val_loss: 0.2695
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 0.0014 - val_loss: 0.2399
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - loss: 0.0012 - val_loss: 0.1968
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 0.0012 - val_loss: 0.1795
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - loss: 0.0011 - val_loss: 0.1576
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - loss: 0.0011 - val_loss: 0.1398
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - loss: 0.0012 - val_loss: 0.1255
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - loss: 0.0013 - val_loss: 0.1269
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - loss: 9.4154e-04 - val_loss: 0.1191
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - loss: 0.0010 - val_loss: 0.1245
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 0.0011 - val_loss: 0.1198
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 183ms/step - loss: 9.2495e-04 - val_loss: 0.1291
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - loss: 9.2563e-04 - val_loss: 0.1317
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - loss: 0.0010 - val_loss: 0.1338
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - loss: 9.1815e-04 - val_loss: 0.1313
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - loss: 9.4001e-04 - val_loss: 0.1262
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - loss: 9.9657e-04 - val_loss: 0.1250
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 7.2225e-04 - val_loss: 0.1277
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - loss: 8.6788e-04 - val_loss: 0.1293
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
#
# Training and evaluating for period: 10_years with head_size: 64, num_heads: 8, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 16s 160ms/step - loss: 1.9053 - val_loss: 0.5796
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - loss: 0.0110 - val_loss: 0.4662
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - loss: 0.0090 - val_loss: 0.4081
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - loss: 0.0067 - val_loss: 0.3667
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 196ms/step - loss: 0.0056 - val_loss: 0.3164
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - loss: 0.0054 - val_loss: 0.2878
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - loss: 0.0046 - val_loss: 0.2370
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - loss: 0.0040 - val_loss: 0.1716
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - loss: 0.0035 - val_loss: 0.1261
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - loss: 0.0031 - val_loss: 0.0699
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - loss: 0.0028 - val_loss: 0.0480
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - loss: 0.0023 - val_loss: 0.0378
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - loss: 0.0024 - val_loss: 0.0260
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - loss: 0.0021 - val_loss: 0.0267
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - loss: 0.0018 - val_loss: 0.0284
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - loss: 0.0018 - val_loss: 0.0323
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - loss: 0.0018 - val_loss: 0.0553
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - loss: 0.0018 - val_loss: 0.0744
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - loss: 0.0014 - val_loss: 0.0988
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - loss: 0.0016 - val_loss: 0.1639
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - loss: 0.0014 - val_loss: 0.1992
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - loss: 0.0015 - val_loss: 0.2560
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - loss: 0.0015 - val_loss: 0.2838
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
#
# Training and evaluating for period: 10_years with head_size: 64, num_heads: 8, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 254ms/step - loss: 3.5858 - val_loss: 0.4599
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - loss: 0.0635 - val_loss: 0.5564
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - loss: 0.0298 - val_loss: 0.1370
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - loss: 0.0129 - val_loss: 3.1023
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0095 - val_loss: 3.0327
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 252ms/step - loss: 0.0078 - val_loss: 2.8397
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 204ms/step - loss: 0.0072 - val_loss: 2.7582
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 245ms/step - loss: 0.0066 - val_loss: 2.6227
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 215ms/step - loss: 0.0064 - val_loss: 2.6235
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 228ms/step - loss: 0.0060 - val_loss: 2.5655
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - loss: 0.0059 - val_loss: 2.5993
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 254ms/step - loss: 0.0060 - val_loss: 2.6349
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 230ms/step - loss: 0.0052 - val_loss: 2.5465
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
#
# Training and evaluating for period: 10_years with head_size: 128, num_heads: 4, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - loss: 1.8257 - val_loss: 8.3365
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - loss: 0.0230 - val_loss: 8.9130
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - loss: 0.0130 - val_loss: 10.7819
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - loss: 0.0093 - val_loss: 12.3055
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - loss: 0.0079 - val_loss: 13.8328
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0070 - val_loss: 15.9785
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - loss: 0.0071 - val_loss: 17.9574
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - loss: 0.0062 - val_loss: 20.2725
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0052 - val_loss: 21.9742
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - loss: 0.0047 - val_loss: 23.1486
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - loss: 0.0040 - val_loss: 23.6098
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
#
# Training and evaluating for period: 10_years with head_size: 128, num_heads: 4, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 233ms/step - loss: 2.7398 - val_loss: 2.9707
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - loss: 0.0296 - val_loss: 2.7094
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - loss: 0.0121 - val_loss: 2.8725
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - loss: 0.0095 - val_loss: 2.9995
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 251ms/step - loss: 0.0083 - val_loss: 3.2516
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 217ms/step - loss: 0.0077 - val_loss: 3.3195
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - loss: 0.0071 - val_loss: 3.3602
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 254ms/step - loss: 0.0066 - val_loss: 3.4910
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - loss: 0.0069 - val_loss: 3.2172
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 241ms/step - loss: 0.0067 - val_loss: 3.2729
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 215ms/step - loss: 0.0067 - val_loss: 3.4703
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - loss: 0.0064 - val_loss: 3.4246
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
#
# Training and evaluating for period: 10_years with head_size: 128, num_heads: 8, ff_dim: 128, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 1.1077 - val_loss: 2.7941
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 284ms/step - loss: 0.0218 - val_loss: 2.9086
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 282ms/step - loss: 0.0127 - val_loss: 2.8859
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 253ms/step - loss: 0.0096 - val_loss: 2.7306
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 0.0085 - val_loss: 2.6938
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 260ms/step - loss: 0.0081 - val_loss: 2.6736
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 13s 285ms/step - loss: 0.0072 - val_loss: 2.4607
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - loss: 0.0066 - val_loss: 2.3582
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 282ms/step - loss: 0.0062 - val_loss: 2.1635
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 273ms/step - loss: 0.0056 - val_loss: 2.1484
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 292ms/step - loss: 0.0047 - val_loss: 2.0650
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 13s 268ms/step - loss: 0.0037 - val_loss: 1.9221
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 284ms/step - loss: 0.0040 - val_loss: 1.9158
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 13s 287ms/step - loss: 0.0031 - val_loss: 1.6764
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 289ms/step - loss: 0.0030 - val_loss: 1.6744
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 13s 287ms/step - loss: 0.0031 - val_loss: 1.6926
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 285ms/step - loss: 0.0025 - val_loss: 1.6445
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 259ms/step - loss: 0.0024 - val_loss: 1.5683
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 0.0022 - val_loss: 1.6835
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - loss: 0.0020 - val_loss: 1.5636
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 286ms/step - loss: 0.0018 - val_loss: 1.5747
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 289ms/step - loss: 0.0017 - val_loss: 1.5622
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - loss: 0.0016 - val_loss: 1.5952
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 346ms/step - loss: 0.0015 - val_loss: 1.6288
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 367ms/step - loss: 0.0015 - val_loss: 1.6435
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 16s 277ms/step - loss: 0.0015 - val_loss: 1.8186
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 286ms/step - loss: 0.0015 - val_loss: 1.9525
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 285ms/step - loss: 0.0012 - val_loss: 1.8378
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 261ms/step - loss: 0.0013 - val_loss: 1.8637
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 292ms/step - loss: 0.0013 - val_loss: 1.9572
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 305ms/step - loss: 0.0012 - val_loss: 1.9493
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 286ms/step - loss: 0.0013 - val_loss: 2.0777
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
#
# Training and evaluating for period: 10_years with head_size: 128, num_heads: 8, ff_dim: 256, num_transformer_blocks: 2
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 32s 500ms/step - loss: 3.9010 - val_loss: 0.8869
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 43s 537ms/step - loss: 0.0338 - val_loss: 0.7440
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 510ms/step - loss: 0.0149 - val_loss: 0.8249
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 488ms/step - loss: 0.0119 - val_loss: 1.0037
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 40s 473ms/step - loss: 0.0093 - val_loss: 1.2669
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 487ms/step - loss: 0.0075 - val_loss: 1.3040
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 25s 535ms/step - loss: 0.0077 - val_loss: 1.5282
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 484ms/step - loss: 0.0072 - val_loss: 1.6762
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 42s 498ms/step - loss: 0.0075 - val_loss: 1.8401
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 25s 532ms/step - loss: 0.0066 - val_loss: 1.9537
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 515ms/step - loss: 0.0060 - val_loss: 2.0775
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 516ms/step - loss: 0.0062 - val_loss: 2.1862
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step
# Best RMSE for period 10_years: 0.21135120108579852 with params: (64, 8, 128, 2)

# %%
import matplotlib.pyplot as plt

# Test 셋 결과 시각화 함수 정의
def plot_test_set_results(best_test_y_predictions, period_name, rmse_value):
    actual, predicted = best_test_y_predictions[period_name]

    plt.figure(figsize=(14, 7))
    plt.plot(actual, label='Actual Values', color='blue')
    plt.plot(predicted, label='Predicted Values', color='orange')
    plt.title(f'Test Set Predictions for {period_name}')
    plt.xlabel('Time')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)

    # RMSE 값을 그래프에 표시
    plt.text(0.95, 0.05, f'RMSE: {rmse_value:.4f}',
             ha='right', va='bottom', transform=plt.gca().transAxes, fontsize=12,
             bbox=dict(facecolor='white', alpha=0.5))

    plt.show()

# 각 기간별로 결과 시각화
for period_name in best_test_y_predictions.keys():
    plot_test_set_results(best_test_y_predictions, period_name, best_results[period_name])
